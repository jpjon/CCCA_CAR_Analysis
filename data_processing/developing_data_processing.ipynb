# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import mapping, MultiPoint
import os
from standardize_data import standardize_car_data
import sys
from geopy.distance import geodesic
from datetime import datetime
from shapely.geometry import LineString
import dask_geopandas as dgpd

# %%
# Define the path to the SICAR folder
sicar_folder = "../data/SICAR/2025"

# Initialize an empty list to store GeoDataFrames
sicar_dataframes = []

# Iterate through each state folder in the SICAR directory
for state_folder in os.listdir(sicar_folder):
    state_path = os.path.join(sicar_folder, state_folder)
    if os.path.isdir(state_path):  # Ensure it's a directory
        # Look for shapefiles in the state folder
        for file in os.listdir(state_path):
            if file.endswith(".shp"):  # Check for shapefiles
                file_path = os.path.join(state_path, file)
                # Load the shapefile i nto a GeoDataFrame
                gdf = gpd.read_file(file_path)
                sicar_dataframes.append(gdf)

# Concatenate all GeoDataFrames into one
car_gdf_later_year = gpd.GeoDataFrame(pd.concat(sicar_dataframes, ignore_index=True))

car_gdf_later_year = standardize_car_data(car_gdf_later_year)
car_gdf_later_year = car_gdf_later_year[['cod_imovel','ind_status', 'ind_tipo','cod_estado', 'geometry']]
car_gdf_later_year = car_gdf_later_year[(car_gdf_later_year['ind_tipo'] == 'IRU') & (car_gdf_later_year['ind_status'].isin(['AT', 'PE']))]
car_gdf_later_year = car_gdf_later_year.drop_duplicates()

# remove invalid geometries
car_gdf_later_year = car_gdf_later_year[car_gdf_later_year.geometry.is_valid]

# For testing purposes, limit the number of rows to 500,000
# car_gdf_later_year = car_gdf_later_year[:250000]

car_gdf_later_year
# Out:
#                                           cod_imovel ind_status ind_tipo  \
# 0        AP-1600253-EFCF2E144B764ED2A5415D65ED0DEC33         AT      IRU
# 1        AP-1600535-479CE6E131594CC4AE247EA06CBDCDE1         AT      IRU
# 2        AP-1600709-9A375D88D9D646C1A6173F709ADAA8B1         AT      IRU
# 3        AP-1600303-8E1CD95C52C7427B96B8345B11F6BD51         AT      IRU
# 4        AP-1600303-B7BAC8D9E06847029ACCFAD835D10687         AT      IRU
# ...                                              ...        ...      ...
# 1405759  RO-1100940-25688D0A876144058634E426B995A3C2         PE      IRU
# 1405760  RO-1100288-45AAAB50BC154B12BB33779A961A3538         PE      IRU
# 1405761  RO-1100130-CBA3543AF3144AB48EAF6F377A5366AB         AT      IRU
# 1405762  RO-1100940-9776279FFBC047018866DF201FFFEC8F         AT      IRU
# 1405763  RO-1100288-E62F9989A7E04168B356331839101B48         AT      IRU
#
#         cod_estado                                           geometry
# 0               AP  POLYGON ((-50.69997 0.60007, -50.6992 0.60119,...
# 1               AP  POLYGON ((-51.97782 0.65532, -51.95378 0.64224...
# 2               AP  POLYGON ((-51.15353 1.55747, -51.14412 1.55216...
# 3               AP  POLYGON ((-51.42971 0.41301, -51.43057 0.41178...
# 4               AP  POLYGON ((-51.04452 0.32683, -51.04411 0.31769...
# ...            ...                                                ...
# 1405759         RO  POLYGON ((-62.42183 -9.3811, -62.41906 -9.3785...
# 1405760         RO  POLYGON ((-61.55923 -11.60997, -61.57016 -11.6...
# 1405761         RO  POLYGON ((-62.32919 -9.18088, -62.33029 -9.177...
# 1405762         RO  POLYGON ((-62.4164 -9.37605, -62.41371 -9.3736...
# 1405763         RO  POLYGON ((-61.57337 -11.62105, -61.57022 -11.6...
#
# [1308967 rows x 5 columns]

# %%
car_gdf_earlier_year = gpd.read_file("../data/SICAR/2024/")
car_gdf_earlier_year = standardize_car_data(car_gdf_earlier_year)
car_gdf_earlier_year = car_gdf_earlier_year[['cod_imovel','ind_status', 'ind_tipo','cod_estado', 'geometry']]
car_gdf_earlier_year = car_gdf_earlier_year[(car_gdf_earlier_year['ind_tipo'] == 'IRU') & (car_gdf_earlier_year['ind_status'].isin(['AT', 'PE']))]
car_gdf_earlier_year = car_gdf_earlier_year.drop_duplicates()

# remove invalid geometries
car_gdf_earlier_year = car_gdf_earlier_year[car_gdf_earlier_year.geometry.is_valid]

# For testing purposes, limit the number of rows to 500,000
# car_gdf_earlier_year = car_gdf_earlier_year[:250000]

car_gdf_earlier_year
# Out:
# /home/jpjon/CCCA_CAR_Analysis/myenv/lib/python3.12/site-packages/pyogrio/raw.py:198: RuntimeWarning: ../data/SICAR/2024/merged_car_2024_02_01_UTF8.shp contains polygon(s) with rings with invalid winding order. Autocorrecting them, but that shapefile should be corrected using ogr2ogr for example.
#   return ogr_read(
#                                           cod_imovel ind_status ind_tipo  \
# 0        AC-1200435-FA1FAFE4584F4A4286756A9DD56A280A         AT      IRU
# 1        AC-1200435-7966BE27C2484A55A1F2B635C710D9F1         AT      IRU
# 4        AC-1200435-AF08DCC29D964FBBAB5870C4C46F4288         AT      IRU
# 5        AC-1200435-AFACFDAA37FC4A789399BE90DE87317E         AT      IRU
# 6        AC-1200435-C78A60C479494D329B5502FFA8280C00         AT      IRU
# ...                                              ...        ...      ...
# 1278773  TO-1715101-FC5798CC6FD34FB283091D672A8144FE         AT      IRU
# 1278774  TO-1715101-FC6614F84E7845E0B0112DEC18A84CB5         AT      IRU
# 1278775  TO-1715101-FDB3736A73BC4195B3363285E7402D8D         AT      IRU
# 1278776  TO-1715101-F1D4F004BD974B65957E346E89B367E2         AT      IRU
# 1278777  TO-1715101-D69731ADC2B44C7B979D0F512D7FAF99         AT      IRU
#
#         cod_estado                                           geometry
# 0               AC  POLYGON ((-70.45394 -9.35226, -70.45281 -9.352...
# 1               AC  POLYGON ((-70.45223 -9.36378, -70.44982 -9.369...
# 4               AC  POLYGON ((-70.54442 -9.56007, -70.54881 -9.561...
# 5               AC  POLYGON ((-69.89842 -9.07162, -69.90032 -9.067...
# 6               AC  POLYGON ((-70.18799 -9.05937, -70.1693 -9.0602...
# ...            ...                                                ...
# 1278773         TO  POLYGON ((-47.71948 -9.98304, -47.72005 -9.984...
# 1278774         TO  POLYGON ((-47.68281 -9.97774, -47.68476 -9.976...
# 1278775         TO  POLYGON ((-47.72366 -10.14515, -47.7176 -10.14...
# 1278776         TO  POLYGON ((-47.7111 -10.07761, -47.72204 -10.08...
# 1278777         TO  POLYGON ((-47.33665 -10.14994, -47.33725 -10.1...
#
# [1195714 rows x 5 columns]

# %%
# Define the path to the PRODES folder
prodes_folder = "../data/PRODES"

# Load the shapefile or GeoJSON file into a GeoDataFrame
# Replace 'filename.shp' with the actual file name in the PRODES folder
prodes_gdf = gpd.read_file(os.path.join(prodes_folder, 'prodes_amazonia_nb.gpkg'))

# Filter only necessary columns in PRODES
# prodes_gdf = prodes_gdf[['uuid', 'geometry']]

prodes_gdf = prodes_gdf.to_crs(car_gdf_earlier_year.crs)

# 1. Add a column to prodes_gdf with the number of exterior corners
def count_corners(geom):
    if geom.geom_type == 'Polygon':
        return len(geom.exterior.coords)
    elif geom.geom_type == 'MultiPolygon':
        return sum(len(poly.exterior.coords) for poly in geom.geoms)
    else:
        return 0

prodes_gdf['num_prodes_corners'] = prodes_gdf.geometry.apply(count_corners)
# Out:
# /home/jpjon/CCCA_CAR_Analysis/myenv/lib/python3.12/site-packages/pyogrio/geopandas.py:265: UserWarning: More than one layer found in 'prodes_amazonia_nb.gpkg': 'accumulated_deforestation_2007_biome' (default), 'hydrography_biome', 'no_forest_biome', 'yearly_deforestation_biome', 'yearly_deforestation_smaller_than_625ha_biome', 'yearly_deforestation_nf_biome', 'residual_biome'. Specify layer parameter to avoid this warning.
#   result = read_func(

# %%
# See the value counts of num_prodes_corners in descending order
prodes_gdf['num_prodes_corners'].value_counts().sort_values(ascending=False).to_clipboard()

# %%
prodes_gdf
# Out:
#        state path_row    main_class class_name  def_cloud  julian_day  \
# 0         RR    23258  DESMATAMENTO      d2007        0.0         0.0
# 1         MA    22062  DESMATAMENTO      d2007        NaN         NaN
# 2         PA    22861  DESMATAMENTO      d2007        0.0         0.0
# 3         MA    22062  DESMATAMENTO      d2007        NaN         NaN
# 4         MA    22062  DESMATAMENTO      d2007        NaN         NaN
# ...      ...      ...           ...        ...        ...         ...
# 187594    PA    22461  DESMATAMENTO      d2007        0.0         0.0
# 187595    PA    22762  DESMATAMENTO      d2007        0.0         0.0
# 187596    PA    22762  DESMATAMENTO      d2007        0.0         0.0
# 187597    PA    22461  DESMATAMENTO      d2007        0.0         0.0
# 187598    RR    23258  DESMATAMENTO      d2007        0.0         0.0
#
#        image_date    year   area_km  scene_id source satellite sensor  \
# 0             NaT  2007.0  0.142381       0.0   None      None   None
# 1             NaT  2007.0  0.065270       NaN   None      None   None
# 2             NaT  2007.0  0.429184       0.0   None      None   None
# 3             NaT  2007.0  0.071416       NaN   None      None   None
# 4             NaT  2007.0  0.081123       NaN   None      None   None
# ...           ...     ...       ...       ...    ...       ...    ...
# 187594        NaT  2007.0  0.302731       0.0   None      None   None
# 187595        NaT  2007.0  1.422563       0.0   None      None   None
# 187596        NaT  2007.0  0.081406       0.0   None      None   None
# 187597        NaT  2007.0  0.218129       0.0   None      None   None
# 187598        NaT  2007.0  0.028464       0.0   None      None   None
#
#                                         uuid  \
# 0       4b610128-b0f0-4b37-831d-cd2310a9314b
# 1       8ca599e7-6ec0-49dc-bc6d-c5f0c3ecd4ed
# 2       f92332bd-081f-4ab5-9c94-19e46beeafb0
# 3       db3cd3d6-f2e3-48d0-ace6-6aa45072fd56
# 4       f4fb7ee4-3b57-48fe-a1c7-7db8c1c87a70
# ...                                      ...
# 187594  3d95b683-8cd8-4ae6-9a81-e4d9a90f7bd8
# 187595  6340f7f7-e827-4ded-af8e-381f840de710
# 187596  c95beb42-2e46-4827-8dd9-b22f54ebe211
# 187597  0e73bed9-7284-4c88-b14e-86e6187f98c3
# 187598  67e9a0f4-61b3-488d-991f-81da3c5bcb58
#
#                                                  geometry  num_prodes_corners
# 0       MULTIPOLYGON (((-60.62819 2.48909, -60.62603 2...                  17
# 1       MULTIPOLYGON (((-43.94949 -3.41601, -43.94949 ...                  14
# 2       MULTIPOLYGON (((-55.86635 -1.43536, -55.86527 ...                  94
# 3       MULTIPOLYGON (((-43.89876 -3.47624, -43.89861 ...                  14
# 4       MULTIPOLYGON (((-43.77845 -2.56747, -43.77829 ...                  58
# ...                                                   ...                 ...
# 187594  MULTIPOLYGON (((-49.83456 -1.53435, -49.83295 ...                  33
# 187595  MULTIPOLYGON (((-53.81336 -3.15857, -53.81336 ...                 256
# 187596  MULTIPOLYGON (((-53.84188 -3.16341, -53.84175 ...                  43
# 187597  MULTIPOLYGON (((-49.68096 -1.67611, -49.67989 ...                  33
# 187598  MULTIPOLYGON (((-61.28024 3, -61.28024 3.00019...                  17
#
# [187599 rows x 16 columns]

# %%
import time

start_time = time.time()

car_ddf = dgpd.from_geopandas(car_gdf_earlier_year, npartitions=40)
prodes_ddf = dgpd.from_geopandas(prodes_gdf, npartitions=40)

sjoin_ddf = car_ddf.sjoin(prodes_ddf, how="inner", predicate="intersects")
car_earlier_year_prodes_intersection_gdf = sjoin_ddf.compute().drop(columns=["index_right"])


end_time = time.time()
print(f"GeoPandas spatial join completed in {end_time - start_time:.2f} seconds.")
# Out:
# GeoPandas spatial join completed in 513.13 seconds.

# %%
car_earlier_year_prodes_intersection_gdf
# Out:
#                                           cod_imovel ind_status ind_tipo  \
# 874      AC-1200450-795058E500084A92AE9A06A69A7AB830         AT      IRU
# 2107     AC-1200450-A0889D901E124F7A88514EFF34B58A0B         AT      IRU
# 2676     AC-1200450-13432135A25840608940F55A2C8F4190         AT      IRU
# 3278     AC-1200500-07B3E50EF06C4614AD92FBE3F254292B         AT      IRU
# 3331     AC-1200500-7738E5F14065418B84BB679422CDDABE         AT      IRU
# ...                                              ...        ...      ...
# 1264765  TO-1709302-25DE0AC8D0174382AC38FD7BF7D800AC         AT      IRU
# 1264767  TO-1709302-DC86B7660B0C43DFB5829C311E3AB929         AT      IRU
# 1273129  TO-1713304-1DBB326ADBFB42BD849E48914A639E04         AT      IRU
# 1273134  TO-1713304-6F045343E18C43DF8FCCD22D7566FF4A         AT      IRU
# 1273172  TO-1713304-F3FB8FE9FC0C4C63ADBEC4C85E5B8A80         AT      IRU
#
#         cod_estado                                           geometry state  \
# 874             AC  POLYGON ((-67.64367 -10.28788, -67.647 -10.286...    AC
# 2107            AC  POLYGON ((-67.33197 -10.05118, -67.33364 -10.0...    AC
# 2676            AC  POLYGON ((-67.25697 -9.92929, -67.25435 -9.932...    AC
# 3278            AC  POLYGON ((-69.25283 -9.82511, -69.25903 -9.818...    AC
# 3331            AC  POLYGON ((-68.72599 -9.26041, -68.72783 -9.263...    AC
# ...            ...                                                ...   ...
# 1264765         TO  POLYGON ((-48.65096 -8.77259, -48.65309 -8.780...    TO
# 1264767         TO  POLYGON ((-48.54725 -8.6051, -48.54339 -8.6177...    TO
# 1273129         TO  POLYGON ((-48.70605 -9.16825, -48.69804 -9.179...    TO
# 1273134         TO  POLYGON ((-48.63476 -9.18103, -48.63084 -9.182...    TO
# 1273172         TO  POLYGON ((-48.74396 -9.18372, -48.74414 -9.184...    TO
#
#         path_row    main_class class_name  def_cloud  julian_day image_date  \
# 874        00267  DESMATAMENTO      d2007        0.0         0.0        NaT
# 2107       00167  DESMATAMENTO      d2007        0.0         0.0        NaT
# 2676       00167  DESMATAMENTO      d2007        0.0         0.0        NaT
# 3278       00367  DESMATAMENTO      d2007        0.0         0.0        NaT
# 3331       00266  DESMATAMENTO      d2007        0.0         0.0        NaT
# ...          ...           ...        ...        ...         ...        ...
# 1264765    22266  DESMATAMENTO      d2007        0.0         0.0        NaT
# 1264767    22266  DESMATAMENTO      d2007        0.0         0.0        NaT
# 1273129    22266  DESMATAMENTO      d2007        0.0         0.0        NaT
# 1273134    22266  DESMATAMENTO      d2007        0.0         0.0        NaT
# 1273172    22266  DESMATAMENTO      d2007        0.0         0.0        NaT
#
#            year      area_km  scene_id source satellite sensor  \
# 874      2007.0     0.024553       0.0   <NA>      <NA>   <NA>
# 2107     2007.0     0.017548       0.0   <NA>      <NA>   <NA>
# 2676     2007.0     0.066705       0.0   <NA>      <NA>   <NA>
# 3278     2007.0     0.012292       0.0   <NA>      <NA>   <NA>
# 3331     2007.0     0.000027       0.0   <NA>      <NA>   <NA>
# ...         ...          ...       ...    ...       ...    ...
# 1264765  2007.0  1096.212921       0.0   <NA>      <NA>   <NA>
# 1264767  2007.0  1096.212921       0.0   <NA>      <NA>   <NA>
# 1273129  2007.0  1096.212921       0.0   <NA>      <NA>   <NA>
# 1273134  2007.0  1096.212921       0.0   <NA>      <NA>   <NA>
# 1273172  2007.0  1096.212921       0.0   <NA>      <NA>   <NA>
#
#                                          uuid  num_prodes_corners
# 874      6c5e03ba-04bc-416d-b897-7660a9c4791e                  13
# 2107     5951a1d3-258c-49c1-9345-2becaee14d1c                   6
# 2676     67b94f70-16c9-4eb7-b0da-c160b5c54bcd                  11
# 3278     9604a82f-e60c-41fc-884d-8532702e3fa7                   6
# 3331     09a62e4a-209e-4989-a2b2-0df6e9c1bf4d                   5
# ...                                       ...                 ...
# 1264765  76fa4cc2-dee7-4ec7-82d5-1e77acac6286                2314
# 1264767  76fa4cc2-dee7-4ec7-82d5-1e77acac6286                2314
# 1273129  76fa4cc2-dee7-4ec7-82d5-1e77acac6286                2314
# 1273134  76fa4cc2-dee7-4ec7-82d5-1e77acac6286                2314
# 1273172  76fa4cc2-dee7-4ec7-82d5-1e77acac6286                2314
#
# [911729 rows x 20 columns]

# %%
# 3. For each cod_imovel, keep the row with the smallest number of corners
car_earlier_year_prodes_intersection_gdf = car_earlier_year_prodes_intersection_gdf.sort_values('num_prodes_corners')
car_earlier_year_prodes_intersection_gdf = car_earlier_year_prodes_intersection_gdf.drop_duplicates(
    subset=['cod_imovel'], keep="first"
)

# %%
# Just for this development script
earlier_year = 2024
later_year=2025

# %%
car_later_year_car_early_year_prodes_intersect = car_earlier_year_prodes_intersection_gdf.merge(
    car_gdf_later_year, 
    on="cod_imovel", 
    how="inner", 
    suffixes=(f"_{earlier_year}", f"_{later_year}")
)

# %%
car_later_year_car_early_year_prodes_intersect
# Out:
#                                          cod_imovel ind_status_2024  \
# 0       MT-5106224-00C3CF7BF11B4201A42F020AA9BA78AB              AT
# 1       MA-2101004-551A8241F12F4075A54FA89E685A0978              AT
# 2       AC-1200385-7AB780C39822499F862D21D3CD8BAE56              AT
# 3       PA-1502707-1430CD99980B46FB90F44BF97EC46A3E              AT
# 4       PA-1502707-005E424A70BF4F3D8D6F7EA50632169F              AT
# ...                                             ...             ...
# 729711  PA-1503705-A1F48EAF674C4742A58ED18E07F3EA29              AT
# 729712  PA-1503705-EAF17A6C141B4544B598AFE77F4FEFF9              AT
# 729713  PA-1503705-F703FE84FD3645FA8938EFA802964044              AT
# 729714  PA-1503705-9E30EFCEEBCE4D85BA4D7BCA2EE5D564              AT
# 729715  PA-1503705-F7CBE381DC794E36A2551CFA2BDB570D              AT
#
#        ind_tipo_2024 cod_estado_2024  \
# 0                IRU              MT
# 1                IRU              MA
# 2                IRU              AC
# 3                IRU              PA
# 4                IRU              PA
# ...              ...             ...
# 729711           IRU              PA
# 729712           IRU              PA
# 729713           IRU              PA
# 729714           IRU              PA
# 729715           IRU              PA
#
#                                             geometry_2024 state path_row  \
# 0       POLYGON ((-56.25845 -13.68172, -56.25819 -13.6...    MT    22769
# 1       POLYGON ((-44.63299 -3.69505, -44.6312 -3.6978...    MA    22162
# 2       POLYGON ((-67.35795 -10.38009, -67.35499 -10.3...    AC    00167
# 3       POLYGON ((-49.3168 -8.35687, -49.31585 -8.3584...    PA    22366
# 4       POLYGON ((-49.31548 -8.36009, -49.3128 -8.3579...    PA    22366
# ...                                                   ...   ...      ...
# 729711  POLYGON ((-49.57141 -5.31115, -49.57114 -5.310...    PA    22464
# 729712  POLYGON ((-50.47817 -5.26896, -50.47189 -5.262...    PA    22464
# 729713  POLYGON ((-49.9641 -5.22824, -49.96614 -5.2308...    PA    22464
# 729714  POLYGON ((-50.36362 -5.18661, -50.36452 -5.188...    PA    22464
# 729715  POLYGON ((-49.97152 -5.39053, -49.97261 -5.393...    PA    22464
#
#           main_class class_name  def_cloud  ...  scene_id source  satellite  \
# 0       DESMATAMENTO      d2007        0.0  ...       0.0   <NA>       <NA>
# 1       DESMATAMENTO      d2007        0.0  ...       0.0   <NA>       <NA>
# 2       DESMATAMENTO      d2007        0.0  ...       0.0   <NA>       <NA>
# 3       DESMATAMENTO      d2007        0.0  ...       0.0   <NA>       <NA>
# 4       DESMATAMENTO      d2007        0.0  ...       0.0   <NA>       <NA>
# ...              ...        ...        ...  ...       ...    ...        ...
# 729711  DESMATAMENTO      d2007        0.0  ...       0.0   <NA>       <NA>
# 729712  DESMATAMENTO      d2007        0.0  ...       0.0   <NA>       <NA>
# 729713  DESMATAMENTO      d2007        0.0  ...       0.0   <NA>       <NA>
# 729714  DESMATAMENTO      d2007        0.0  ...       0.0   <NA>       <NA>
# 729715  DESMATAMENTO      d2007        0.0  ...       0.0   <NA>       <NA>
#
#         sensor                                  uuid num_prodes_corners  \
# 0         <NA>  88055420-006f-4956-883a-7ad8f8881e3b                  4
# 1         <NA>  94df47a8-3cf5-4bb2-9254-c1bdbc9befd4                  4
# 2         <NA>  c621417b-0234-421d-a086-f046bcbbe839                  4
# 3         <NA>  29f54d83-8503-4726-afae-de0466a86e47                  4
# 4         <NA>  29f54d83-8503-4726-afae-de0466a86e47                  4
# ...        ...                                   ...                ...
# 729711    <NA>  73802038-3cc0-4783-9e87-bd3e249ed16c              67805
# 729712    <NA>  73802038-3cc0-4783-9e87-bd3e249ed16c              67805
# 729713    <NA>  73802038-3cc0-4783-9e87-bd3e249ed16c              67805
# 729714    <NA>  73802038-3cc0-4783-9e87-bd3e249ed16c              67805
# 729715    <NA>  73802038-3cc0-4783-9e87-bd3e249ed16c              67805
#
#        ind_status_2025 ind_tipo_2025 cod_estado_2025  \
# 0                   AT           IRU              MT
# 1                   AT           IRU              MA
# 2                   AT           IRU              AC
# 3                   AT           IRU              PA
# 4                   AT           IRU              PA
# ...                ...           ...             ...
# 729711              AT           IRU              PA
# 729712              AT           IRU              PA
# 729713              AT           IRU              PA
# 729714              AT           IRU              PA
# 729715              AT           IRU              PA
#
#                                             geometry_2025
# 0       POLYGON ((-56.25845 -13.68172, -56.25819 -13.6...
# 1       POLYGON ((-44.63299 -3.69505, -44.6312 -3.6978...
# 2       POLYGON ((-67.35795 -10.38009, -67.35499 -10.3...
# 3       POLYGON ((-49.3168 -8.35687, -49.31585 -8.3584...
# 4       POLYGON ((-49.31548 -8.36009, -49.3128 -8.3579...
# ...                                                   ...
# 729711  POLYGON ((-49.57141 -5.31115, -49.57114 -5.310...
# 729712  POLYGON ((-50.47817 -5.26896, -50.47189 -5.262...
# 729713  POLYGON ((-49.9641 -5.22824, -49.96614 -5.2308...
# 729714  POLYGON ((-50.36362 -5.18661, -50.36452 -5.188...
# 729715  POLYGON ((-49.97152 -5.39053, -49.97261 -5.393...
#
# [729716 rows x 24 columns]

# %%
# Sitaution where tehre are duplicates from early year to later year, for either because merge has two differnt status' for later year or because later year has two duplicates of same cod_imovel
car_later_year_car_early_year_prodes_intersect = car_later_year_car_early_year_prodes_intersect.drop_duplicates(subset=['cod_imovel'], keep="first")

# %%
car_later_year_car_early_year_prodes_intersect = car_later_year_car_early_year_prodes_intersect.copy()

car_later_year_car_early_year_prodes_intersect['geometry_changed'] = \
    car_later_year_car_early_year_prodes_intersect.apply(
        lambda row: not row[f'geometry_{earlier_year}'].equals(row[f'geometry_{later_year}']),
        axis=1
    )

# %%
# Merge PRODES geometry
car_later_year_car_early_year_prodes_intersect_with_prodes = car_later_year_car_early_year_prodes_intersect.merge(
    prodes_gdf[['uuid', 'geometry']],
    on='uuid',
    how='inner'
).rename(columns={'geometry': 'geometry_prodes'})

# %%
(car_later_year_car_early_year_prodes_intersect_with_prodes.geometry_prodes)
# Out:
# 0         MULTIPOLYGON (((-60.23195 -12.45474, -60.23195...
# 1         MULTIPOLYGON (((-50.12484 -9.34592, -50.12484 ...
# 2         MULTIPOLYGON (((-50.05519 -9.18336, -50.05519 ...
# 3         MULTIPOLYGON (((-57.54693 -13.29225, -57.54601...
# 4         MULTIPOLYGON (((-50.13439 -9.31988, -50.1345 -...
#                                 ...
# 729643    MULTIPOLYGON (((-49.63961 -5.5766, -49.63961 -...
# 729644    MULTIPOLYGON (((-49.63961 -5.5766, -49.63961 -...
# 729645    MULTIPOLYGON (((-49.63961 -5.5766, -49.63961 -...
# 729646    MULTIPOLYGON (((-49.63961 -5.5766, -49.63961 -...
# 729647    MULTIPOLYGON (((-49.63961 -5.5766, -49.63961 -...
# Name: geometry_prodes, Length: 729648, dtype: geometry

# %%
car_later_year_car_early_year_prodes_intersect_with_prodes.loc[5, 'geometry_prodes']
# Out:
# <MULTIPOLYGON (((-50.25 -9.375, -50.25 -9.375, -50.249 -9.373, -50.25 -9.375)))>

# %%
from dask.diagnostics import ProgressBar

# Convert to Dask GeoDataFrame
ddf = dgpd.from_geopandas(car_later_year_car_early_year_prodes_intersect_with_prodes, npartitions=20)

def filter_func(df):
    mask = (
        df['geometry_changed'] &
        ~df.apply(lambda row: row[f'geometry_{later_year}'].intersects(row['geometry_prodes']), axis=1)
    )
    return df[mask]

start_time = time.time()

with ProgressBar():
    filtered_ddf = ddf.map_partitions(filter_func)
    test = filtered_ddf.compute()
end_time = time.time()

print(f"Filtering completed in {end_time - start_time:.2f} seconds.")
# Out:
# [###############                         ] | 38% Completed | 584.87 s

# %%
# Filter for cadastras that have changed yoy and where they have been changed to no longer intersect with prodes geometries
start_time = time.time()

filtered_indexes = []

for row in car_later_year_car_early_year_prodes_intersect_with_prodes.itertuples():
    if row.geometry_changed and not row.__getattribute__(f'geometry_{later_year}').intersects(row.geometry_prodes):
        filtered_indexes.append(row.Index)

car_later_year_car_early_year_prodes_intersect_with_prodes = car_later_year_car_early_year_prodes_intersect_with_prodes.loc[filtered_indexes]      
end_time = time.time()
print(f"GeoPandas filter completed in {end_time - start_time:.2f} seconds.")

car_later_year_car_early_year_prodes_intersect_with_prodes
# Out:
# GeoPandas filter completed in 89.80 seconds.
#                                         cod_imovel ind_status_2024  \
# 1      AC-1200385-3A4D314004B04E50AAD52886A21F1012              PE
# 50     AC-1200302-681D7D27A5184D069BE499860B2225ED              AT
# 59     AM-1301704-62F7A5753A734BCC99491D323621DACA              AT
# 128    AC-1200138-ED7569A8A4694F4B99ABE9EEE27AD7E9              AT
# 198    AC-1200807-8C639C42A6FE4E81A806F9E8EC6B0CF2              AT
# ...                                            ...             ...
# 89700  AC-1200179-56629BA07F474CDBBC0F47863F93A522              AT
# 90449  AC-1200401-6F948FC009D24F65BA37CFEF44470A18              PE
# 90840  AC-1200401-BA1EA76DABB94C58A0217B49A6F4EA59              AT
# 90924  AC-1200450-D1A621956EBD4ADBB0001E659A637B49              AT
# 92948  AC-1200401-BE6786FAA08B4478AFC08E024EC6DBA0              AT
#
#       ind_tipo_2024 cod_estado_2024  \
# 1               IRU              AC
# 50              IRU              AC
# 59              IRU              AM
# 128             IRU              AC
# 198             IRU              AC
# ...             ...             ...
# 89700           IRU              AC
# 90449           IRU              AC
# 90840           IRU              AC
# 90924           IRU              AC
# 92948           IRU              AC
#
#                                            geometry_2024 state path_row  \
# 1      POLYGON ((-67.4446 -10.43599, -67.43717 -10.44...    AC    00167
# 50     POLYGON ((-70.2277 -8.40352, -70.21877 -8.4077...    AC    00366
# 59     POLYGON ((-63.24587 -7.6098, -63.23445 -7.6082...    AM    23265
# 128    POLYGON ((-68.27799 -9.81225, -68.27535 -9.815...    AC    00267
# 198    POLYGON ((-67.42181 -9.58915, -67.42743 -9.586...    AC    00267
# ...                                                  ...   ...      ...
# 89700  POLYGON ((-67.90744 -10.31559, -67.90555 -10.3...    AC    00267
# 90449  POLYGON ((-68.24744 -9.9306, -68.2429 -9.93135...    AC    00267
# 90840  POLYGON ((-68.51261 -9.8009, -68.50976 -9.7816...    AC    00267
# 90924  POLYGON ((-67.53699 -10.08219, -67.52854 -10.0...    AC    00267
# 92948  POLYGON ((-68.12974 -10.13697, -68.11987 -10.1...    AC    00267
#
#          main_class class_name  def_cloud  ...  satellite sensor  \
# 1      DESMATAMENTO      d2007        0.0  ...       None   None
# 50     DESMATAMENTO      d2007        0.0  ...       None   None
# 59     DESMATAMENTO      d2007        0.0  ...       None   None
# 128    DESMATAMENTO      d2007        0.0  ...       None   None
# 198    DESMATAMENTO      d2007        0.0  ...       None   None
# ...             ...        ...        ...  ...        ...    ...
# 89700  DESMATAMENTO      d2007        0.0  ...       None   None
# 90449  DESMATAMENTO      d2007        0.0  ...       None   None
# 90840  DESMATAMENTO      d2007        0.0  ...       None   None
# 90924  DESMATAMENTO      d2007        0.0  ...       None   None
# 92948  DESMATAMENTO      d2007        0.0  ...       None   None
#
#                                        uuid  num_prodes_corners  \
# 1      7c2d4fee-861b-4c74-9a23-8c2bf4f41ab5                   4
# 50     9377ef49-0656-4b65-bd2d-62afe8f2f573                   5
# 59     2db8dee6-33b7-4d9f-9e43-094e577f9682                   5
# 128    240a54c7-30fb-4dda-a9cb-014bd79a98ec                   5
# 198    eb9f02c9-0440-4707-8ebd-cf252df3381a                   5
# ...                                     ...                 ...
# 89700  3ef09fc0-37d0-436c-891d-3958efae91ea               51892
# 90449  3ef09fc0-37d0-436c-891d-3958efae91ea               51892
# 90840  3ef09fc0-37d0-436c-891d-3958efae91ea               51892
# 90924  3ef09fc0-37d0-436c-891d-3958efae91ea               51892
# 92948  3ef09fc0-37d0-436c-891d-3958efae91ea               51892
#
#        ind_status_2025 ind_tipo_2025 cod_estado_2025  \
# 1                   PE           IRU              AC
# 50                  AT           IRU              AC
# 59                  AT           IRU              AM
# 128                 AT           IRU              AC
# 198                 AT           IRU              AC
# ...                ...           ...             ...
# 89700               AT           IRU              AC
# 90449               PE           IRU              AC
# 90840               AT           IRU              AC
# 90924               PE           IRU              AC
# 92948               AT           IRU              AC
#
#                                            geometry_2025 geometry_changed  \
# 1      POLYGON ((-67.44549 -10.44008, -67.44206 -10.4...             True
# 50     POLYGON ((-70.2113 -8.39339, -70.21183 -8.3960...             True
# 59     POLYGON ((-63.23448 -7.63633, -63.25235 -7.636...             True
# 128    POLYGON ((-68.27125 -9.81056, -68.27263 -9.811...             True
# 198    POLYGON ((-67.39973 -9.58031, -67.40392 -9.584...             True
# ...                                                  ...              ...
# 89700  POLYGON ((-67.92657 -10.37263, -67.93308 -10.3...             True
# 90449  POLYGON ((-68.24714 -9.93067, -68.2429 -9.9313...             True
# 90840  POLYGON ((-68.50176 -9.75745, -68.50098 -9.757...             True
# 90924  POLYGON ((-67.51812 -10.14916, -67.52923 -10.1...             True
# 92948  POLYGON ((-68.70566 -10.12217, -68.71045 -10.1...             True
#
#                                          geometry_prodes
# 1      MULTIPOLYGON (((-67.44868 -10.45387, -67.44868...
# 50     MULTIPOLYGON (((-70.22933 -8.40784, -70.22933 ...
# 59     MULTIPOLYGON (((-63.25 -7.6167, -63.24986 -7.6...
# 128    MULTIPOLYGON (((-68.27613 -9.81496, -68.27589 ...
# 198    MULTIPOLYGON (((-67.42958 -9.58039, -67.42958 ...
# ...                                                  ...
# 89700  MULTIPOLYGON (((-68.7157 -9.90919, -68.7157 -9...
# 90449  MULTIPOLYGON (((-68.7157 -9.90919, -68.7157 -9...
# 90840  MULTIPOLYGON (((-68.7157 -9.90919, -68.7157 -9...
# 90924  MULTIPOLYGON (((-68.7157 -9.90919, -68.7157 -9...
# 92948  MULTIPOLYGON (((-68.7157 -9.90919, -68.7157 -9...
#
# [679 rows x 26 columns]

# %%
car_later_year_car_early_year_prodes_intersect_with_prodes.geometry_prodes.duplicated(keep=False).sum()
# Out:
# np.int64(142)

# %%
# Function to calculate geodesic distance between centroids
def calculate_geodesic_distance(row):
    coord_earlier_year = (row[f'centroid_{earlier_year}'].y, row[f'centroid_{earlier_year}'].x)  # (lat, lon)
    coord_later_year = (row[f'centroid_{later_year}'].y, row[f'centroid_{later_year}'].x)
    return round(geodesic(coord_earlier_year, coord_later_year).meters, 3)

car_later_year_car_early_year_prodes_intersect_with_prodes[f'centroid_{earlier_year}'] = car_later_year_car_early_year_prodes_intersect_with_prodes[f'geometry_{earlier_year}'].centroid
car_later_year_car_early_year_prodes_intersect_with_prodes[f'centroid_{later_year}'] = car_later_year_car_early_year_prodes_intersect_with_prodes[f'geometry_{later_year}'].centroid
# Out:
# /tmp/ipykernel_71650/3275230540.py:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   car_later_year_car_early_year_prodes_intersect_with_prodes[f'centroid_{earlier_year}'] = car_later_year_car_early_year_prodes_intersect_with_prodes[f'geometry_{earlier_year}'].centroid
# /tmp/ipykernel_71650/3275230540.py:8: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   car_later_year_car_early_year_prodes_intersect_with_prodes[f'centroid_{later_year}'] = car_later_year_car_early_year_prodes_intersect_with_prodes[f'geometry_{later_year}'].centroid

# %%
car_later_year_car_early_year_prodes_intersect_with_prodes['geodesic_distance'] = car_later_year_car_early_year_prodes_intersect_with_prodes.apply(calculate_geodesic_distance, axis=1)
car_later_year_car_early_year_prodes_intersect_with_prodes
# Out:
#                                         cod_imovel ind_status_2024  \
# 3      AC-1200385-3A4D314004B04E50AAD52886A21F1012              PE
# 21     AC-1200807-8C639C42A6FE4E81A806F9E8EC6B0CF2              AT
# 41     AM-1300706-8ACD1C86A4544CB8B9E8FB14243F4D0C              AT
# 107    AC-1200013-E454568CE3EA4A2893E20A9FE40C3265              AT
# 136    AM-1301209-BAAA08B04FE54192A9126C20677CE438              AT
# ...                                            ...             ...
# 89590  AC-1200708-91D79F8AD95B4FFCBC73D73C5AC53218              AT
# 90152  AC-1200450-D1A621956EBD4ADBB0001E659A637B49              AT
# 91154  AC-1200708-108F7F12AB5B44489A479C682D0A598B              PE
# 91264  AC-1200401-6F948FC009D24F65BA37CFEF44470A18              PE
# 93391  AC-1200401-BA1EA76DABB94C58A0217B49A6F4EA59              AT
#
#       ind_tipo_2024 cod_estado_2024  \
# 3               IRU              AC
# 21              IRU              AC
# 41              IRU              AM
# 107             IRU              AC
# 136             IRU              AM
# ...             ...             ...
# 89590           IRU              AC
# 90152           IRU              AC
# 91154           IRU              AC
# 91264           IRU              AC
# 93391           IRU              AC
#
#                                            geometry_2024  \
# 3      POLYGON ((-67.4446 -10.43599, -67.43717 -10.44...
# 21     POLYGON ((-67.42181 -9.58915, -67.42743 -9.586...
# 41     POLYGON ((-67.49063 -9.33147, -67.49168 -9.329...
# 107    POLYGON ((-66.84828 -10.02053, -66.88501 -10.0...
# 136    POLYGON ((-63.10097 -4.16275, -63.10097 -4.162...
# ...                                                  ...
# 89590  POLYGON ((-68.44385 -10.60681, -68.44363 -10.6...
# 90152  POLYGON ((-67.53699 -10.08219, -67.52854 -10.0...
# 91154  POLYGON ((-68.57204 -10.56886, -68.57392 -10.5...
# 91264  POLYGON ((-68.24744 -9.9306, -68.2429 -9.93135...
# 93391  POLYGON ((-68.51261 -9.8009, -68.50976 -9.7816...
#
#                                        uuid  num_prodes_corners  \
# 3      7c2d4fee-861b-4c74-9a23-8c2bf4f41ab5                   4
# 21     9c8a9cd6-f907-4e1c-a4cc-b0097f656e2c                   5
# 41     7dd0bc54-05c9-4f0a-9dd9-9a2c73fe8d88                   5
# 107    21090479-6d6f-404e-851e-54e1f7bf83d5                   5
# 136    a326402f-2b36-4477-b97f-2f182d9d3d81                   5
# ...                                     ...                 ...
# 89590  3ef09fc0-37d0-436c-891d-3958efae91ea               51892
# 90152  3ef09fc0-37d0-436c-891d-3958efae91ea               51892
# 91154  3ef09fc0-37d0-436c-891d-3958efae91ea               51892
# 91264  3ef09fc0-37d0-436c-891d-3958efae91ea               51892
# 93391  3ef09fc0-37d0-436c-891d-3958efae91ea               51892
#
#       ind_status_2025 ind_tipo_2025 cod_estado_2025  \
# 3                  PE           IRU              AC
# 21                 AT           IRU              AC
# 41                 AT           IRU              AM
# 107                AT           IRU              AC
# 136                AT           IRU              AM
# ...               ...           ...             ...
# 89590              AT           IRU              AC
# 90152              PE           IRU              AC
# 91154              PE           IRU              AC
# 91264              PE           IRU              AC
# 93391              AT           IRU              AC
#
#                                            geometry_2025  geometry_changed  \
# 3      POLYGON ((-67.44549 -10.44008, -67.44206 -10.4...              True
# 21     POLYGON ((-67.39973 -9.58031, -67.40392 -9.584...              True
# 41     POLYGON ((-67.49004 -9.33025, -67.49202 -9.332...              True
# 107    POLYGON ((-66.83038 -10.03735, -66.83501 -10.0...              True
# 136    POLYGON ((-63.10139 -4.16306, -63.09517 -4.158...              True
# ...                                                  ...               ...
# 89590  POLYGON ((-68.44494 -10.59867, -68.44498 -10.5...              True
# 90152  POLYGON ((-67.51812 -10.14916, -67.52923 -10.1...              True
# 91154  POLYGON ((-68.5761 -10.53163, -68.57531 -10.53...              True
# 91264  POLYGON ((-68.24714 -9.93067, -68.2429 -9.9313...              True
# 93391  POLYGON ((-68.50176 -9.75745, -68.50098 -9.757...              True
#
#                                          geometry_prodes  \
# 3      MULTIPOLYGON (((-67.44868 -10.45387, -67.44868...
# 21     MULTIPOLYGON (((-67.42985 -9.58066, -67.42985 ...
# 41     MULTIPOLYGON (((-67.50033 -9.31194, -67.50011 ...
# 107    MULTIPOLYGON (((-66.88072 -10.00085, -66.88072...
# 136    MULTIPOLYGON (((-63.09871 -4.15952, -63.09871 ...
# ...                                                  ...
# 89590  MULTIPOLYGON (((-68.7157 -9.90919, -68.7157 -9...
# 90152  MULTIPOLYGON (((-68.7157 -9.90919, -68.7157 -9...
# 91154  MULTIPOLYGON (((-68.7157 -9.90919, -68.7157 -9...
# 91264  MULTIPOLYGON (((-68.7157 -9.90919, -68.7157 -9...
# 93391  MULTIPOLYGON (((-68.7157 -9.90919, -68.7157 -9...
#
#                      centroid_2024                centroid_2025  \
# 3      POINT (-67.44537 -10.44602)  POINT (-67.45064 -10.44702)
# 21      POINT (-67.42698 -9.58294)   POINT (-67.40988 -9.58023)
# 41      POINT (-67.50178 -9.31925)   POINT (-67.49025 -9.31947)
# 107    POINT (-66.88997 -10.03213)  POINT (-66.87673 -10.04898)
# 136      POINT (-63.0982 -4.15955)   POINT (-63.09775 -4.16187)
# ...                            ...                          ...
# 89590  POINT (-68.44631 -10.60587)  POINT (-68.44494 -10.59861)
# 90152  POINT (-67.53507 -10.08475)  POINT (-67.52424 -10.14859)
# 91154  POINT (-68.57303 -10.56411)  POINT (-68.57581 -10.53205)
# 91264   POINT (-68.24552 -9.93168)     POINT (-68.2454 -9.9317)
# 93391    POINT (-68.50772 -9.7917)   POINT (-68.50149 -9.75781)
#
#        geodesic_distance
# 3                587.050
# 21              1901.204
# 41              1267.175
# 107             2362.270
# 136              260.643
# ...                  ...
# 89590            817.680
# 90152           7161.221
# 91154           3559.019
# 91264             14.016
# 93391           3810.272
#
# [681 rows x 16 columns]

# %%
from shapely.geometry import LineString

# can drop iru later to cut down data size

car_later_year_car_early_year_prodes_intersect_with_prodes['distance_line'] = car_later_year_car_early_year_prodes_intersect_with_prodes.apply(
    lambda row: LineString([row[f'geometry_{earlier_year}'].centroid, row[f'geometry_{later_year}'].centroid]),
    axis=1
)

car_later_year_car_early_year_prodes_intersect_with_prodes.head(1)
# Out:
#                                     cod_imovel ind_status_2024 ind_tipo_2024  \
# 3  AC-1200385-3A4D314004B04E50AAD52886A21F1012              PE           IRU
#
#   cod_estado_2024                                      geometry_2024  \
# 3              AC  POLYGON ((-67.4446 -10.43599, -67.43717 -10.44...
#
#                                    uuid  num_prodes_corners ind_status_2025  \
# 3  7c2d4fee-861b-4c74-9a23-8c2bf4f41ab5                   4              PE
#
#   ind_tipo_2025 cod_estado_2025  \
# 3           IRU              AC
#
#                                        geometry_2025  geometry_changed  \
# 3  POLYGON ((-67.44549 -10.44008, -67.44206 -10.4...              True
#
#                                      geometry_prodes  \
# 3  MULTIPOLYGON (((-67.44868 -10.45387, -67.44868...
#
#                  centroid_2024                centroid_2025  \
# 3  POINT (-67.44537 -10.44602)  POINT (-67.45064 -10.44702)
#
#    geodesic_distance                                      distance_line
# 3             587.05  LINESTRING (-67.44537 -10.44602, -67.45064 -10...

# %%
car_later_year_car_early_year_prodes_intersect_with_prodes.geometry_prodes
# Out:
# 3        MULTIPOLYGON (((-67.44868 -10.45387, -67.44868...
# 21       MULTIPOLYGON (((-67.42985 -9.58066, -67.42985 ...
# 41       MULTIPOLYGON (((-67.50033 -9.31194, -67.50011 ...
# 107      MULTIPOLYGON (((-66.88072 -10.00085, -66.88072...
# 136      MULTIPOLYGON (((-63.09871 -4.15952, -63.09871 ...
#                                ...
# 89590    MULTIPOLYGON (((-68.7157 -9.90919, -68.7157 -9...
# 90152    MULTIPOLYGON (((-68.7157 -9.90919, -68.7157 -9...
# 91154    MULTIPOLYGON (((-68.7157 -9.90919, -68.7157 -9...
# 91264    MULTIPOLYGON (((-68.7157 -9.90919, -68.7157 -9...
# 93391    MULTIPOLYGON (((-68.7157 -9.90919, -68.7157 -9...
# Name: geometry_prodes, Length: 681, dtype: geometry

# %%
car_later_year_car_early_year_prodes_intersect_with_prodes.num_prodes_corners.describe()
# Out:
# count      681.000000
# mean      2582.280470
# std       8626.100618
# min          4.000000
# 25%         11.000000
# 50%         26.000000
# 75%        112.000000
# max      51892.000000
# Name: num_prodes_corners, dtype: float64

# %%
# Filter for MultiPolygons with more than one polygon
multipolys_with_multiple = prodes_gdf[
    prodes_gdf.geometry.apply(lambda g: g.geom_type == 'MultiPolygon' and len(g.geoms) > 1)
].copy()

# Add an area column (in the CRS units, usually degrees or meters)
multipolys_with_multiple['area'] = multipolys_with_multiple.geometry.area

# Filter where area is greater than 10
multipolys_with_multiple = multipolys_with_multiple[multipolys_with_multiple['area'] > 1]

multipolys_with_multiple
# Out:
# /tmp/ipykernel_60256/2944272340.py:7: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   multipolys_with_multiple['area'] = multipolys_with_multiple.geometry.area
# Empty GeoDataFrame
# Columns: [uuid, geometry, num_edges, area]
# Index: []

# %%
multipolys_with_multiple.iloc[53].geometry
# Out:
# <MULTIPOLYGON (((-47.092 -5.478, -47.092 -5.478, -47.094 -5.478, -47.092 -5....>

# %%
prodes_gdf
# Out:
#                                         uuid  \
# 0       4b610128-b0f0-4b37-831d-cd2310a9314b
# 1       8ca599e7-6ec0-49dc-bc6d-c5f0c3ecd4ed
# 2       f92332bd-081f-4ab5-9c94-19e46beeafb0
# 3       db3cd3d6-f2e3-48d0-ace6-6aa45072fd56
# 4       f4fb7ee4-3b57-48fe-a1c7-7db8c1c87a70
# ...                                      ...
# 187594  3d95b683-8cd8-4ae6-9a81-e4d9a90f7bd8
# 187595  6340f7f7-e827-4ded-af8e-381f840de710
# 187596  c95beb42-2e46-4827-8dd9-b22f54ebe211
# 187597  0e73bed9-7284-4c88-b14e-86e6187f98c3
# 187598  67e9a0f4-61b3-488d-991f-81da3c5bcb58
#
#                                                  geometry
# 0       MULTIPOLYGON (((-60.62819 2.48909, -60.62603 2...
# 1       MULTIPOLYGON (((-43.94949 -3.41601, -43.94949 ...
# 2       MULTIPOLYGON (((-55.86635 -1.43536, -55.86527 ...
# 3       MULTIPOLYGON (((-43.89876 -3.47624, -43.89861 ...
# 4       MULTIPOLYGON (((-43.77845 -2.56747, -43.77829 ...
# ...                                                   ...
# 187594  MULTIPOLYGON (((-49.83456 -1.53435, -49.83295 ...
# 187595  MULTIPOLYGON (((-53.81336 -3.15857, -53.81336 ...
# 187596  MULTIPOLYGON (((-53.84188 -3.16341, -53.84175 ...
# 187597  MULTIPOLYGON (((-49.68096 -1.67611, -49.67989 ...
# 187598  MULTIPOLYGON (((-61.28024 3, -61.28024 3.00019...
#
# [187599 rows x 2 columns]

# %%
# timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

# # Use the timestamp in the output directory
# output_dir = f'./outputs/{timestamp}'
# os.makedirs(output_dir, exist_ok=True)

# fields_to_keep = [
#     'cod_imovel', f'ind_status_{later_year}', f'cod_estado_{later_year}',
#     'geodesic_distance'
# ]

# geometry_columns = {
#     f"geometry_{earlier_year}": f"geometry_{earlier_year}.geojson",
#     f"geometry_{later_year}": f"geometry_{later_year}.geojson",
#     f"geometry_prodes": "geometry_prodes.geojson",
#     f"distance_line": "distance_lines.geojson"
# }

# target_crs = "EPSG:4674"

# for geom_col, filename in geometry_columns.items():
#     gdf_out = car_later_year_car_early_year_prodes_intersect_with_prodes[fields_to_keep + [geom_col]].copy()
#     gdf_out = gdf_out.set_geometry(geom_col)
    
#     # Set CRS if not already set
#     if gdf_out.crs is None:
#         gdf_out = gdf_out.set_crs(target_crs)
#     else:
#         # Reproject to EPSG:4674 if needed
#         gdf_out = gdf_out.to_crs(target_crs)
    
#     gdf_out.to_file(os.path.join(output_dir, filename), driver="GeoJSON")
